# %%
# %pip install tensorflow cupy
import tensorflow as tf
# Out:
# ...
#   Using cached cupy-13.3.0.tar.gz (3.4 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# ...
# Using cached fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (53 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [3995 lines of output]
#       Generating cache key from header files...
#       Cache key (1610 files matching /tmp/pip-install-wu5uc0lp/cupy_7dde6ffa17164ff5bdc114c244c37b33/cupy/_core/include/**): 06242053f6eab1bf334c20abeca9ffd799b650a5
#       Clearing directory: /tmp/pip-install-wu5uc0lp/cupy_7dde6ffa17164ff5bdc114c244c37b33/cupy/.data
#
#       -------- Configuring Module: cuda --------
#
#       -------- Configuring Module: cusolver --------
#
#       -------- Configuring Module: cudnn --------
#
# ...
